# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.3.3

# %%
print(pd.__name__)
# Out:
# pandas

# %%
countries = pd.Series(
    data = ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    index = ['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ'],
    name = 'countries'
)
display(countries)
# Out:
# UK       Англия
# CA       Канада
# US          США
# RU       Россия
# UA      Украина
# BY     Беларусь
# KZ    Казахстан
# Name: countries, dtype: object

# %%
# names = ['chlorhexidine', 'cyntomycin', 'afobazol']
# counts = [15, 18, 7]

import pandas as pd

def create_medications(names, counts):
    medications = pd.Series(
        data = counts,
        index = names,
        name = 'medicati'
    )
    return medications

def get_percent(medications, name):
    return medications[name] / medications.sum() * 100

names=['chlorhexidine', 'cyntomycin', 'afobazol']
counts=[15, 18, 7]
medications = create_medications(names, counts)


print(medications)
print(get_percent(medications, 'chlorhexidine'))
# Out:
# chlorhexidine    15
# cyntomycin       18
# afobazol          7
# Name: medicati, dtype: int64
# 37.5

# %%
import pandas as pd

income = [478, 512, 196]
expenses = [156, 130, 270]
years = [2018, 2019, 2020]


def create_companyDF(income, expenses, years):
    df = pd.DataFrame(
        {
        'Income': income,
        'Expenses': expenses
        },
        index = years
    )
    return df

def get_profit(df, year):
    if year not in df.index:
        return None

    return df.loc[year, 'Income'] - df.loc[year, 'Expenses']

# %%
countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'area': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})

countries_df.to_csv('/Users/artempolyakov/Documents/Курсы/СкилФектори/IDE/Блок 1 (прочие файлы)/Pandas/Skillfactory/countries.csv', index=False, sep=';')

# %%
countries_data = pd.read_csv('/Users/artempolyakov/Documents/Курсы/СкилФектори/IDE/Блок 1 (прочие файлы)/Pandas/Skillfactory/countries.csv', sep=';')
display(countries_data)
# Out:
#      country  population      area
# 0     Англия       56.29    133396
# 1     Канада       38.05   9984670
# 2        США      322.28   9826630
# 3     Россия      146.24  17125191
# 4    Украина       45.50    603628
# 5   Беларусь        9.50    207600
# 6  Казахстан       17.04   2724902

# %%
data = pd.read_csv('https://raw.githubusercontent.com/esabunor/MLWorkspace/master/melb_data.csv')
display(data)
# Out:
#        Unnamed: 0        Suburb           Address  Rooms Type      Price  \
# 0               1    Abbotsford      85 Turner St      2    h  1480000.0
# 1               2    Abbotsford   25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford      5 Charles St      3    h  1465000.0
# 3               5    Abbotsford  40 Federation La      3    h   850000.0
# 4               6    Abbotsford       55a Park St      4    h  1600000.0
# ...           ...           ...               ...    ...  ...        ...
# 18391       23540  Williamstown   8/2 Thompson St      2    t   622500.0
# 18392       23541  Williamstown      96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie      17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville        6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville     33 Freeman St      4    h  1050000.0
#
#       Method     SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# ...

# %%
melb_data = pd.read_csv('/Users/artempolyakov/Documents/Курсы/СкилФектори/IDE/Блок 1 (прочие файлы)/Pandas/Skillfactory/melb_data.csv', sep=',')
# display(melb_data)


# # df.loc[year, 'Income']

# print(melb_data.loc[15, 'Price'])
# print(melb_data.loc[90, 'Date'])

# 3521 - Landsize
# 1690

# print(melb_data.loc[3521, 'Landsize']/melb_data.loc[1690, 'Landsize'])

display(melb_data.head(7))
# melb_data.info()

# melb_data['Car'] = melb_data['Car'].astype('int64')
# melb_data['Bedroom'] = melb_data['Bedroom'].astype('int64')
# melb_data['Bathroom'] = melb_data['Bathroom'].astype('int64')
# melb_data['Propertycount'] = melb_data['Propertycount'].astype('int64')
# melb_data['YearBuilt'] = melb_data['YearBuilt'].astype('int64')
# melb_data.info()


# melb_data.describe().loc[:, ['Distance', 'BuildingArea' , 'Price']]
melb_data['Type'].value_counts(normalize=True)

# melb_data.describe()
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
# 5      5  Abbotsford    129 Charles St      2    h   941000.0      S  Jellis
# 6      6  Abbotsford      124 Yarra St      3    h  1876000.0      S  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...  1.0     202.0         126.0     1970.0
# 1  4/02/2016       2.5  ...  0.0     156.0          79.0     1900.0
# 2  4/03/2017       2.5  ...  0.0     134.0         150.0     1900.0
# 3  4/03/2017       2.5  ...  1.0      94.0         126.0     1970.0
# ...

# %%
print(melb_data['Price'].mean(axis=0))
# 1075684.079455081
# Out:
# 1075684.079455081

# %%
print(round(melb_data['Distance'].std()))
# Out:
# 6

# %%
BuildingArea_median = melb_data['BuildingArea'].median()
BuildingArea_mean = melb_data['BuildingArea'].mean()

print((BuildingArea_median - BuildingArea_mean)/BuildingArea_mean)
# Out:
# -0.09764079662364533

# %%
# Rooms

print(melb_data['Rooms'].mode())
# Out:
# 0    3
# Name: Rooms, dtype: int64

# %%
melb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  float64
#  12  Bathroom       13580 non-null  float64
#  13  Car            13580 non-null  float64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  float64
# ...

# %%
print(melb_data[melb_data['Bathroom'] == 0].count)
# Out:
# <bound method DataFrame.count of        index           Suburb            Address  Rooms Type      Price  \
# 139      139       Alphington        6 Naroon Rd      3    h  1485000.0
# 281      281         Armadale    3/50 Denbigh Rd      2    u   546000.0
# 505      505        Balaclava     5/11 Albion St      2    u   497500.0
# 584      584           Balwyn     5 Shrimpton Ct      2    h  1010000.0
# 913      913   Bentleigh East    579 Warrigal Rd      3    h   700000.0
# 1063    1063         Brighton          17 New St      3    h  1900000.0
# 1070    1070         Brighton        1/5 Webb St      3    t  1067000.0
# 1593    1593       Camberwell   5 Nicholsdale Rd      4    h  1400000.0
# 2253    2253      Elsternwick    5/29 Nepean Hwy      2    u   410000.0
# 2777    2777        Glen Iris         25 Hope St      2    h   845000.0
# 2797    2797        Glen Iris        130 High St      4    h  1550000.0
# 2808    2808        Glen Iris    1/64 Edgar St N      2    u   545000.0
# ...

# %%
# print(melb_data[(melb_data['SellerG'] == 'Nelson') & (melb_data['Price'] >= 3000000)].shape[0])

f_price = melb_data[melb_data['BuildingArea'] == 0]

print(f_price['Price'].min())
# Out:
# 412500.0

# %%
filt = melb_data[(melb_data['Price'] < 1000000) & ((melb_data['Rooms'] > 5) | (melb_data['YearBuilt'] > 2015))]

print(round(filt['Price'].mean()))
# Out:
# 769239

# %%
import pandas as pd

# 1. Загружаем данные в переменную (укажите корректный путь к исходному файлу)
students_performance = pd.read_csv(
    '/Users/artempolyakov/Documents/Курсы/СкилФектори/IDE/Блок 1 (прочие файлы)/Pandas/Skillfactory/students_performance.csv'
)

# 2. Проверяем, что данные загрузились
display(students_performance.head(10))

students_performance.info()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
# test preparation course
fltr = students_performance['math score'] == 0
mean_score = students_performance.loc[fltr, 'gender'].count()
print(mean_score)
# Out:
# 1

# %%
# Группируем по lunch, выбираем все скоры и применяем describe()
table_1 = (
    students_performance
    .groupby('lunch')[['math score', 'reading score', 'writing score']]
    .describe()
    .round(2) # Округляем все числа до 2 знаков для удобства чтения
)
display(table_1)
# Out:
#              math score                                               \
#                   count   mean    std   min   25%   50%   75%    max
# lunch
# free/reduced      355.0  58.92  15.16   0.0  49.0  60.0  69.0  100.0
# standard          645.0  70.03  13.65  19.0  61.0  69.0  80.0  100.0
#
#              reading score         ...              writing score         \
#                      count   mean  ...   75%    max         count   mean
# lunch                              ...
# free/reduced         355.0  64.65  ...  75.0  100.0         355.0  63.02
# standard             645.0  71.65  ...  82.0  100.0         645.0  70.82
#
#
#                 std   min   25%   50%   75%    max
# lunch
# free/reduced  15.43  10.0  53.0  64.0  74.0  100.0
# standard      14.34  22.0  62.0  72.0  81.0  100.0
#
# [2 rows x 24 columns]

# %%
students_performance['parental level of education'].value_counts(normalize=True)
# Out:
# parental level of education
# some college          0.226
# associate's degree    0.222
# high school           0.196
# some high school      0.179
# bachelor's degree     0.118
# master's degree       0.059
# Name: proportion, dtype: float64

# %%
import pandas as pd

data = pd.read_csv('https://raw.githubusercontent.com/esabunor/MLWorkspace/master/melb_data.csv', sep = ',')
# display(data)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18396 entries, 0 to 18395
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     18396 non-null  int64
#  1   Suburb         18396 non-null  object
#  2   Address        18396 non-null  object
#  3   Rooms          18396 non-null  int64
#  4   Type           18396 non-null  object
#  5   Price          18396 non-null  float64
#  6   Method         18396 non-null  object
#  7   SellerG        18396 non-null  object
#  8   Date           18396 non-null  object
#  9   Distance       18395 non-null  float64
#  10  Postcode       18395 non-null  float64
#  11  Bedroom2       14927 non-null  float64
#  12  Bathroom       14925 non-null  float64
#  13  Car            14820 non-null  float64
#  14  Landsize       13603 non-null  float64
#  15  BuildingArea   7762 non-null   float64
#  16  YearBuilt      8958 non-null   float64
# ...

# %%
data_2 = data.copy()
data_2.head(5)
# Out:
#    Unnamed: 0      Suburb           Address  Rooms Type      Price Method  \
# 0           1  Abbotsford      85 Turner St      2    h  1480000.0      S
# 1           2  Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2           4  Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3           5  Abbotsford  40 Federation La      3    h   850000.0     PI
# 4           6  Abbotsford       55a Park St      4    h  1600000.0     VB
#
#   SellerG       Date  Distance  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  Biggin  3/12/2016       2.5  ...       1.0  1.0     202.0           NaN
# 1  Biggin  4/02/2016       2.5  ...       1.0  0.0     156.0          79.0
# 2  Biggin  4/03/2017       2.5  ...       2.0  0.0     134.0         150.0
# 3  Biggin  4/03/2017       2.5  ...       2.0  1.0      94.0           NaN
# 4  Nelson  4/06/2016       2.5  ...       1.0  2.0     120.0         142.0
#
# ...

# %%
data_2 = data_2.drop(['index', 'Coordinates'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data_2 = data_2.drop(['index', 'Coordinates'], axis=1)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)
#    5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)
#    5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
# ...

# %%
import pandas as pd

# data = pd.read_csv('https://raw.githubusercontent.com/esabunor/MLWorkspace/master/melb_data.csv', sep = ',')
# # display(data)
# data.info()


total_rooms = data_2['Rooms'] + data_2['Bedroom2'] + data_2['Bathroom']
display(total_rooms)
# Out:
# 0         5.0
# 1         5.0
# 2         8.0
# 3         8.0
# 4         8.0
#          ...
# 18391     6.0
# 18392     9.0
# 18393    11.0
# 18394     9.0
# 18395    10.0
# Length: 18396, dtype: float64

# %%
data_2['MeanRoomsArea'] = data_2['BuildingArea'] / total_rooms
display(data_2['MeanRoomsArea'])
# Out:
# 0              NaN
# 1        15.800000
# 2        18.750000
# 3              NaN
# 4        17.750000
#            ...
# 18391    14.833333
# 18392    17.444444
# 18393          NaN
# 18394    12.444444
# 18395    13.900000
# Name: MeanRoomsArea, Length: 18396, dtype: float64

# %%
diff_area = data_2['BuildingArea'] - data_2['Landsize']
sum_area = data_2['BuildingArea'] + data_2['Landsize']
data_2['AreaRatio'] = diff_area/sum_area
display(data_2['AreaRatio'])

# data_2.info()
# Out:
# 0             NaN
# 1       -0.327660
# 2        0.056338
# 3             NaN
# 4        0.083969
#            ...
# 18391         NaN
# 18392   -0.693060
# 18393         NaN
# 18394   -0.527426
# 18395         NaN
# Name: AreaRatio, Length: 18396, dtype: float64

# %%
countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'area': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})

# display(countries_df)
countries_df["plotnost"] = countries_df["population"]*1000000 / countries_df["area"]

# display(countries_df)
countries_df.describe()
# Out:
#        population          area    plotnost
# count    7.000000  7.000000e+00    7.000000
# mean    90.700000  5.800860e+06   84.930806
# std    111.603714  6.605919e+06  150.858453
# min      9.500000  1.333960e+05    3.810842
# 25%     27.545000  4.056140e+05    7.396451
# 50%     45.500000  2.724902e+06   32.796595
# 75%    101.265000  9.905650e+06   60.569315
# max    322.280000  1.712519e+07  421.976671

# %%
data_2['Date'] = pd.to_datetime(data_2['Date'], dayfirst=True)
display(data_2['Date'])
# Out:
# 0       2016-12-03
# 1       2016-02-04
# 2       2017-03-04
# 3       2017-03-04
# 4       2016-06-04
#            ...
# 18391   2017-08-26
# 18392   2017-08-26
# 18393   2017-08-26
# 18394   2017-08-26
# 18395   2017-08-26
# Name: Date, Length: 18396, dtype: datetime64[ns]

# %%
years_sold = data_2['Date'].dt.year
print(years_sold)
print('Min year sold:', years_sold.min())
print('Max year sold:', years_sold.max())
print('Mode year sold:', years_sold.mode()[0])
# Out:
# 0        2016
# 1        2016
# 2        2017
# 3        2017
# 4        2016
#          ...
# 18391    2017
# 18392    2017
# 18393    2017
# 18394    2017
# 18395    2017
# Name: Date, Length: 18396, dtype: int32
# Min year sold: 2016
# Max year sold: 2017
# Mode year sold: 2017

# %%
data_2['WeekdaySale'] = data_2['Date'].dt.day_of_week
data_2['WeekdaySale'].value_counts()
15902+1533
# Out:
# 17435

# %%
data_2 = data_2.drop('YearBuilt', axis=1)

# %%
ufo = pd.read_csv('/Users/artempolyakov/Documents/Курсы/СкилФектори/IDE/Блок 1 (прочие файлы)/Pandas/Skillfactory/ufo.csv', sep = ',')

ufo.head(5)
ufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18241 entries, 0 to 18240
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   City             18215 non-null  object
#  1   Colors Reported  2882 non-null   object
#  2   Shape Reported   15597 non-null  object
#  3   State            18241 non-null  object
#  4   Time             18241 non-null  object
# dtypes: object(5)
# memory usage: 712.7+ KB

# %%
import pandas as pd

ufo["Time"] = pd.to_datetime(ufo["Time"], dayfirst=True)
ufo["Year_of"] = ufo["Time"].dt.year
ufo["State"].value_counts()


ufo.tail(2)
# Out:
#               City Colors Reported Shape Reported State                Time  \
# 18239  Eagle River             RED          LIGHT    WI 2000-12-31 23:45:00
# 18240         Ybor             NaN           OVAL    FL 2000-12-31 23:59:00
#
#        Year_of
# 18239     2000
# 18240     2000

# %%
ufo.head(5)
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time  Year_of
# 0 1930-06-01 22:00:00     1930
# 1 1930-06-30 20:00:00     1930
# 2 1931-02-15 14:00:00     1931
# 3 1931-06-01 13:00:00     1931
# 4 1933-04-18 19:00:00     1933

# %%
# ufo["State"].value_counts()

ufo[ufo["State"] == 'NV']
# Out:
#              City Colors Reported Shape Reported State                Time  \
# 76      Las Vegas             NaN           DISK    NV 1947-07-15 10:00:00
# 172    Nellis AFB             NaN           DISK    NV 1952-02-17 18:00:00
# 565        Fallon             NaN           OVAL    NV 1959-09-15 00:00:00
# 566     Goldfield             NaN          LIGHT    NV 1959-09-15 01:00:00
# 613           NaN             NaN           DISK    NV 1960-07-01 12:00:00
# ...           ...             ...            ...   ...                 ...
# 17447    Laughlin             NaN      FORMATION    NV 2000-09-16 22:00:00
# 17567   Las Vegas             NaN         SPHERE    NV 2000-09-30 22:25:00
# 17617   Las Vegas      RED YELLOW          OTHER    NV 2000-10-06 20:25:00
# 17890        Reno             NaN       TRIANGLE    NV 2000-11-07 02:15:00
# 18104   Las Vegas             NaN       TRIANGLE    NV 2000-12-10 17:30:00
#
#        Year_of
# 76        1947
# 172       1952
# 565       1959
# ...

# %%
import pandas as pd

ufo = pd.read_csv("ufo.csv")

ufo["Time"] = pd.to_datetime(ufo["Time"])

answer = ufo.loc[ufo["State"] == "NV", "Time"].diff().dt.days.mean()

round(answer, 2)
# Out:
# np.float64(68.45)

# %%
print(data_2['Address'].nunique())
# Out:
# 18134

# %%
print(data_2['Address'].loc[177])
print(data_2['Address'].loc[1812])
print(data_2['Address'].loc[9001])
# Out:
# 38 Bennett St
# 58a Cassels Rd
# 83 Kingsville St

# %%
# На вход данной функции поступает строка с адресом.
def get_street_type(address):
# Создаём список географических пометок exclude_list.
    exclude_list = ['N', 'S', 'W', 'E']
# Метод split() разбивает строку на слова по пробелу.
# В результате получаем список слов в строке и заносим его в переменную address_list.
    address_list = address.split(' ')
# Обрезаем список, оставляя в нём только последний элемент,
# потенциальный подтип улицы, и заносим в переменную street_type.
    street_type = address_list[-1]
# Делаем проверку на то, что полученный подтип является географической пометкой.
# Для этого проверяем его на наличие в списке exclude_list.
    if street_type in exclude_list:
# Если переменная street_type является географической пометкой,
# переопределяем её на второй элемент с конца списка address_list.
        street_type = address_list[-2]
# Возвращаем переменную street_type, в которой хранится подтип улицы.
    return street_type

# %%
street_types = data_2['Address'].apply(get_street_type)
display(street_types)
# Out:
# 0        St
# 1        St
# 2        St
# 3        La
# 4        St
#          ..
# 18391    St
# 18392    St
# 18393    Wy
# 18394    St
# 18395    St
# Name: Address, Length: 18396, dtype: object

# %%
display(street_types.nunique())
# Out:
# 89

# %%
display(street_types.value_counts())
# Out:
# Address
# St         9588
# Rd         3525
# Av         1736
# Ct          748
# Cr          574
#            ...
# Loop          1
# Qy            1
# Terrace       1
# Glade         1
# Corso         1
# Name: count, Length: 89, dtype: int64

# %%
popular_stypes =street_types.value_counts().nlargest(10).index
print(popular_stypes)
# Out:
# Index(['St', 'Rd', 'Av', 'Ct', 'Cr', 'Dr', 'Gr', 'Pde', 'Pl', 'Wy'], dtype='object', name='Address')

# %%
data_2['StreetType'] = street_types.apply(lambda x: x if x in popular_stypes else 'other')
display(data_2['StreetType'])
# Out:
# 0           St
# 1           St
# 2           St
# 3        other
# 4           St
#          ...
# 18391       St
# 18392       St
# 18393       Wy
# 18394       St
# 18395       St
# Name: StreetType, Length: 18396, dtype: object

# %%
data_2 = data_2.drop('Address', axis=1)

# %%
data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18396 entries, 0 to 18395
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     18396 non-null  int64
#  1   Suburb         18396 non-null  object
#  2   Rooms          18396 non-null  int64
#  3   Type           18396 non-null  object
#  4   Price          18396 non-null  float64
#  5   Method         18396 non-null  object
#  6   SellerG        18396 non-null  object
#  7   Date           18396 non-null  datetime64[ns]
#  8   Distance       18395 non-null  float64
#  9   Postcode       18395 non-null  float64
#  10  Bedroom2       14927 non-null  float64
#  11  Bathroom       14925 non-null  float64
#  12  Car            14820 non-null  float64
#  13  Landsize       13603 non-null  float64
#  14  BuildingArea   7762 non-null   float64
#  15  CouncilArea    12233 non-null  object
#  16  Lattitude      15064 non-null  float64
# ...

# %%
popular_seller =data_2["SellerG"].value_counts().nlargest(49).index
data_2["SellerG"] = data_2["SellerG"].apply(lambda x: x if x in popular_seller else 'other')
display(data_2['SellerG'])
# Out:
# 0            Biggin
# 1            Biggin
# 2            Biggin
# 3            Biggin
# 4            Nelson
#             ...
# 18391          Greg
# 18392       Sweeney
# 18393    Buckingham
# 18394       Village
# 18395       Village
# Name: SellerG, Length: 18396, dtype: object

# %%
# data_2["SellerG" in ("Nelson", "other")].groupby("Price")["SellerG"].min()


nelson_min_price = data_2[data_2["SellerG"] == "Nelson"]["Price"].min()

other_min_price = data_2[data_2["SellerG"] == "other"]["Price"].min()

answer = round(nelson_min_price / other_min_price, 1)

answer
# Out:
# np.float64(2.0)

# %%
# создаём пустой список
unique_list = []
# пробегаемся по именам столбцов в таблице
for col in data_2.columns:
    # создаём кортеж (имя столбца, число уникальных значений)
    item = (col, data_2[col].nunique(),data_2[col].dtypes)
    # добавляем кортеж в список
    unique_list.append(item)
# создаём вспомогательную таблицу и сортируем её
unique_counts = pd.DataFrame(
    unique_list,
    columns=['Column_Name', 'Num_Unique', 'Type']
).sort_values(by='Num_Unique',  ignore_index=True)
# выводим её на экран
display(unique_counts)
# Out:
#       Column_Name  Num_Unique            Type
# 0            Type           3          object
# 1     WeekdaySale           5           int32
# 2          Method           5          object
# 3      Regionname           8          object
# 4        Bathroom           9         float64
# 5             Car          11         float64
# 6      StreetType          11          object
# 7           Rooms          11           int64
# 8       MonthSale          12           int32
# 9        Bedroom2          12         float64
# 10    CouncilArea          33          object
# 11        SellerG          50          object
# 12           Date          58  datetime64[ns]
# 13       Postcode         205         float64
# 14       Distance         210         float64
# 15  Propertycount         324         float64
# 16         Suburb         330          object
# 17   BuildingArea         613         float64
# 18  MeanRoomsArea        1302         float64
# ...

# %%
display(data_2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18396 entries, 0 to 18395
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     18396 non-null  int64
#  1   Suburb         18396 non-null  object
#  2   Rooms          18396 non-null  int64
#  3   Type           18396 non-null  object
#  4   Price          18396 non-null  float64
#  5   Method         18396 non-null  object
#  6   SellerG        18396 non-null  object
#  7   Date           18396 non-null  datetime64[ns]
#  8   Distance       18395 non-null  float64
#  9   Postcode       18395 non-null  float64
#  10  Bedroom2       14927 non-null  float64
#  11  Bathroom       14925 non-null  float64
#  12  Car            14820 non-null  float64
#  13  Landsize       13603 non-null  float64
#  14  BuildingArea   7762 non-null   float64
#  15  CouncilArea    12233 non-null  object
#  16  Lattitude      15064 non-null  float64
# ...

# %%
cols_to_exclude = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car'] # список столбцов, которые мы не берём во внимание
max_unique_count = 150 # задаём максимальное число уникальных категорий
for col in data_2.columns: # цикл по именам столбцов
    if data_2[col].nunique() < max_unique_count and col not in cols_to_exclude: # проверяем условие
        data_2[col] = data_2[col].astype('category') # преобразуем тип столбца
display(data_2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18396 entries, 0 to 18395
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     18396 non-null  int64
#  1   Suburb         18396 non-null  object
#  2   Rooms          18396 non-null  int64
#  3   Type           18396 non-null  category
#  4   Price          18396 non-null  float64
#  5   Method         18396 non-null  category
#  6   SellerG        18396 non-null  category
#  7   Date           18396 non-null  datetime64[ns]
#  8   Distance       18395 non-null  float64
#  9   Postcode       18395 non-null  float64
#  10  Bedroom2       14927 non-null  category
#  11  Bathroom       14925 non-null  float64
#  12  Car            14820 non-null  float64
#  13  Landsize       13603 non-null  float64
#  14  BuildingArea   7762 non-null   float64
#  15  CouncilArea    12233 non-null  category
#  16  Lattitude      15064 non-null  float64
# ...
